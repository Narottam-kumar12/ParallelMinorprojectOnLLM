# %%
# !pip3 install tiktoken
# Out:
# Collecting tiktoken
#   Using cached tiktoken-0.9.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.12/site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2025.7.14)
# Using cached tiktoken-0.9.0-cp312-cp312-macosx_11_0_arm64.whl (1.0 MB)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.9.0

# %%
import tiktoken
import importlib

print("tiktoken version :",importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version : 0.9.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|  In the sunlint terraces"
    "of soomeunknownPlace. kjnjjyiuhvyiotcgyighfyv"
)
integers = tokenizer.encode(text, allowed_special = {"<|endoftext|>"})
print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 1279, 91, 437, 1659, 5239, 91, 220, 554, 262, 4252, 75, 600, 8812, 2114, 1659, 523, 462, 34680, 27271, 13, 479, 73, 77, 41098, 48111, 7456, 7670, 5151, 66, 1360, 394, 24928, 85]

# %%
string = tokenizer.decode(integers)
print(string)
# Out:
# Hello, do you like tea? <|endoftext|  In the sunlint terracesof soomeunknownPlace. kjnjjyiuhvyiotcgyighfyv
